# %%
# %matplotlib inline
import scipy
import numpy as np
import matplotlib.pyplot as plt

# %%
a_pascal = scipy.io.wavfile.read("files/pascal/a.wav")[1]

# %%
plt.plot(a_pascal)

# %%
fft = np.fft.fft(a_pascal)

# %%
plt.plot(fft)

# %%
plt.magnitude_spectrum(a_pascal,Fs=8000)
# Out:
# (array([ 18393.29367595,  57101.69984257,  78892.70546883, ...,
#           5151.95996429,   6426.63185386,  14427.34676572]),
#  array([  0.00000000e+00,   5.94000594e-01,   1.18800119e+00, ...,
#           3.99881200e+03,   3.99940600e+03,   4.00000000e+03]),
#  <matplotlib.lines.Line2D at 0x7f385cae5400>)
